# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")
pd.set_option("display.max_columns",None)

# %%
travel=pd.read_csv("google_review_ratings.csv")

# %%
travel
# Out:
#            Category 1  Category 2  Category 3  Category 4  Category 5  \
# User
# User 1           0.00        0.00        3.63        3.65        5.00
# User 2           0.00        0.00        3.63        3.65        5.00
# User 3           0.00        0.00        3.63        3.63        5.00
# User 4           0.00        0.50        3.63        3.63        5.00
# User 5           0.00        0.00        3.63        3.63        5.00
# ...               ...         ...         ...         ...         ...
# User 5452        0.91        5.00        4.00        2.79        2.77
# User 5453        0.93        5.00        4.02        2.79        2.78
# User 5454        0.94        5.00        4.03        2.80        2.78
# User 5455        0.95        4.05        4.05        2.81        2.79
# User 5456        0.95        4.07        5.00        2.82        2.80
#
#            Category 6  Category 7  Category 8  Category 9  Category 10  \
# User
# ...

# %%
travel.isnull().sum()
# Out:
# Category 1        0
# Category 2        0
# Category 3        0
# Category 4        0
# Category 5        0
# Category 6        0
# Category 7        0
# Category 8        0
# Category 9        0
# Category 10       0
# Category 11       0
# Category 12       1
# Category 13       0
# Category 14       0
# Category 15       0
# Category 16       0
# Category 17       0
# Category 18       0
# Category 19       0
# Category 20       0
# Category 21       0
# Category 22       0
# Category 23       0
# Category 24       1
# Unnamed: 25    5454
# dtype: int64

# %%
travel.shape
# Out:
# (5456, 25)

# %%
travel.describe()
# Out:
#         Category 1   Category 2   Category 3   Category 4   Category 5  \
# count  5456.000000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      1.455720     2.319707     2.489331     2.796886     2.958941
# std       0.827604     1.421438     1.247815     1.309159     1.339056
# min       0.000000     0.000000     0.000000     0.830000     1.120000
# 25%       0.920000     1.360000     1.540000     1.730000     1.770000
# 50%       1.340000     1.905000     2.060000     2.460000     2.670000
# 75%       1.810000     2.682500     2.740000     4.092500     4.312500
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        Category 6   Category 7   Category 8   Category 9  Category 10  \
# count  5456.00000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      2.89349     3.351395     2.540795     3.126019     2.832729
# std       1.28240     1.413492     1.111391     1.356802     1.307665
# ...

# %%
travel.drop(["Unnamed: 25"],axis=1,inplace=True)

# %%
travel
# Out:
#            Category 1  Category 2  Category 3  Category 4  Category 5  \
# User
# User 1           0.00        0.00        3.63        3.65        5.00
# User 2           0.00        0.00        3.63        3.65        5.00
# User 3           0.00        0.00        3.63        3.63        5.00
# User 4           0.00        0.50        3.63        3.63        5.00
# User 5           0.00        0.00        3.63        3.63        5.00
# ...               ...         ...         ...         ...         ...
# User 5452        0.91        5.00        4.00        2.79        2.77
# User 5453        0.93        5.00        4.02        2.79        2.78
# User 5454        0.94        5.00        4.03        2.80        2.78
# User 5455        0.95        4.05        4.05        2.81        2.79
# User 5456        0.95        4.07        5.00        2.82        2.80
#
#            Category 6  Category 7  Category 8  Category 9  Category 10  \
# User
# ...

# %%
travel.isnull().sum()
# Out:
# Category 1     0
# Category 2     0
# Category 3     0
# Category 4     0
# Category 5     0
# Category 6     0
# Category 7     0
# Category 8     0
# Category 9     0
# Category 10    0
# Category 11    0
# Category 12    1
# Category 13    0
# Category 14    0
# Category 15    0
# Category 16    0
# Category 17    0
# Category 18    0
# Category 19    0
# Category 20    0
# Category 21    0
# Category 22    0
# Category 23    0
# Category 24    1
# dtype: int64

# %%
travel=travel.dropna()

# %%
travel.isnull().sum()
# Out:
# Category 1     0
# Category 2     0
# Category 3     0
# Category 4     0
# Category 5     0
# Category 6     0
# Category 7     0
# Category 8     0
# Category 9     0
# Category 10    0
# Category 11    0
# Category 12    0
# Category 13    0
# Category 14    0
# Category 15    0
# Category 16    0
# Category 17    0
# Category 18    0
# Category 19    0
# Category 20    0
# Category 21    0
# Category 22    0
# Category 23    0
# Category 24    0
# dtype: int64

# %%
travel['Category 11']=travel['Category 11'].astype(float)

# %%
travel['Category 11'].unique()
# Out:
# array([1.7 , 1.73, 1.71, 1.69, 1.67, 1.65, 1.66, 1.64, 1.63, 5.  , 1.56,
#        1.55, 1.53, 1.52, 1.51, 1.5 , 1.49, 1.48, 1.46, 2.13, 2.12, 2.1 ,
#        2.09, 2.08, 2.07, 2.06, 2.05, 2.04, 2.03, 2.01, 2.  , 1.98, 1.97,
#        1.95, 1.93, 1.91, 1.9 , 1.88, 1.86, 1.84, 1.83, 1.81, 1.79, 1.77,
#        1.74, 1.72, 1.68, 1.61, 1.6 , 1.59, 1.58, 1.99, 2.47, 2.35, 2.48,
#        2.59, 3.39, 2.31, 2.78, 2.79, 2.77, 2.76, 2.75, 2.74, 2.72, 2.71,
#        2.69, 2.68, 2.66, 2.65, 2.63, 2.61, 2.57, 2.55, 2.53, 2.51, 2.49,
#        1.94, 1.92, 1.82, 1.76, 1.62, 4.08, 4.04, 4.02, 4.01, 4.  , 3.99,
#        3.98, 3.96, 3.95, 3.94, 3.93, 3.91, 3.9 , 3.88, 3.87, 3.86, 3.84,
#        3.85, 2.17, 3.  , 2.99, 2.82, 2.83, 2.81, 2.8 , 2.73, 2.67, 2.64,
#        2.62, 2.54, 2.52, 2.5 , 2.02, 1.57, 1.54, 1.47, 1.87, 1.85, 1.78,
#        2.6 , 1.45, 1.43, 1.41, 1.39, 1.37, 1.36, 1.34, 1.32, 1.3 , 1.28,
#        1.26, 1.24, 1.22, 1.2 , 1.18, 1.16, 1.14, 1.12, 1.1 , 1.08, 1.07,
# ...

# %%
travel['Category 10'].unique()
# Out:
# array([2.64, 2.65, 2.63, 2.62, 5.  , 2.33, 2.31, 2.3 , 2.29, 2.28, 2.27,
#        1.65, 1.64, 1.63, 2.23, 2.22, 2.21, 2.2 , 1.57, 1.56, 1.55, 2.18,
#        2.17, 2.16, 2.15, 2.14, 2.13, 2.12, 2.11, 2.42, 2.41, 2.83, 2.81,
#        2.8 , 2.79, 2.77, 2.76, 2.75, 2.74, 2.72, 2.71, 2.69, 2.68, 2.67,
#        2.61, 2.6 , 2.09, 2.07, 2.05, 2.04, 1.67, 1.62, 1.6 , 1.59, 1.58,
#        1.97, 2.45, 2.46, 1.98, 2.47, 2.9 , 2.87, 1.69, 3.92, 3.91, 3.9 ,
#        3.89, 3.88, 3.87, 3.94, 4.5 , 4.49, 4.48, 3.85, 3.83, 3.82, 3.81,
#        3.8 , 3.79, 3.78, 3.77, 3.76, 3.74, 3.72, 3.71, 3.7 , 3.69, 3.67,
#        3.66, 3.64, 3.63, 3.62, 3.6 , 3.59, 3.57, 3.56, 3.54, 3.53, 3.51,
#        3.5 , 3.48, 3.47, 3.45, 3.44, 3.42, 3.41, 3.4 , 3.38, 3.35, 3.33,
#        3.32, 3.29, 3.28, 3.27, 3.25, 3.24, 3.21, 3.2 , 3.18, 3.17, 3.16,
#        2.02, 2.01, 1.99, 3.09, 3.1 , 3.12, 3.11, 3.07, 3.06, 3.05, 3.04,
#        3.03, 3.01, 2.99, 2.82, 2.78, 2.7 , 2.66, 4.38, 4.39, 4.4 , 1.76,
# ...

# %%
travel.columns=['churches', 'resorts', 'beaches', 'parks', 'theatres', 'museums', 'malls', 'zoo', 'restaurants', 'pubs/bars',
               'localservices', 'burger/pizza shops', 'hotels/other lodgings','juice bars', 'art galleries', 'dance clubs', 
               'swimming pools', 'gyms', 'bakeries', 'beauty & spas', 'cafes', 'viewpoints', 'monuments', 'gardens']

# %%
travel.head()
# Out:
#         churches  resorts  beaches  parks  theatres  museums  malls   zoo  \
# User
# User 1       0.0      0.0     3.63   3.65       5.0     2.92    5.0  2.35
# User 2       0.0      0.0     3.63   3.65       5.0     2.92    5.0  2.64
# User 3       0.0      0.0     3.63   3.63       5.0     2.92    5.0  2.64
# User 4       0.0      0.5     3.63   3.63       5.0     2.92    5.0  2.35
# User 5       0.0      0.0     3.63   3.63       5.0     2.92    5.0  2.64
#
#         restaurants  pubs/bars  localservices  burger/pizza shops  \
# User
# User 1         2.33       2.64           1.70                1.69
# User 2         2.33       2.65           1.70                1.69
# User 3         2.33       2.64           1.70                1.69
# User 4         2.33       2.64           1.73                1.69
# User 5         2.33       2.64           1.70                1.69
#
#         hotels/other lodgings  juice bars  art galleries  dance clubs  \
# User
# ...

# %%
travel.describe()
# Out:
#           churches      resorts      beaches        parks     theatres  \
# count  5454.000000  5454.000000  5454.000000  5454.000000  5454.000000
# mean      1.455746     2.320048     2.489059     2.797103     2.958904
# std       0.827732     1.421576     1.247503     1.309188     1.338785
# min       0.000000     0.000000     0.000000     0.830000     1.120000
# 25%       0.920000     1.360000     1.540000     1.730000     1.770000
# 50%       1.340000     1.910000     2.060000     2.460000     2.670000
# 75%       1.810000     2.687500     2.740000     4.097500     4.310000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#            museums        malls          zoo  restaurants    pubs/bars  \
# count  5454.000000  5454.000000  5454.000000  5454.000000  5454.000000
# mean      2.893423     3.351476     2.541177     3.126542     2.832695
# std       1.282101     1.413291     1.111398     1.356774     1.307299
# ...

# %%
import scipy.cluster.hierarchy as shc 
plt.figure(figsize=(10,7)) 
plt.title("Dendrograms") 
dend = shc.dendrogram(shc.linkage(travel,method="ward"))

# %%
plt.figure(figsize=(10,7))
plt.title("Dendograms")
dend=shc.dendrogram(shc.linkage(travel, method="ward"))
plt.axhline(y=180, color='r',linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
Y_pred = cluster.fit_predict(travel)

# %%
travel["Clusters"]=Y_pred
travel
# Out:
#            churches  resorts  beaches  parks  theatres  museums  malls   zoo  \
# User
# User 1         0.00     0.00     3.63   3.65      5.00     2.92   5.00  2.35
# User 2         0.00     0.00     3.63   3.65      5.00     2.92   5.00  2.64
# User 3         0.00     0.00     3.63   3.63      5.00     2.92   5.00  2.64
# User 4         0.00     0.50     3.63   3.63      5.00     2.92   5.00  2.35
# User 5         0.00     0.00     3.63   3.63      5.00     2.92   5.00  2.64
# ...             ...      ...      ...    ...       ...      ...    ...   ...
# User 5452      0.91     5.00     4.00   2.79      2.77     2.57   2.43  1.09
# User 5453      0.93     5.00     4.02   2.79      2.78     2.57   1.77  1.07
# User 5454      0.94     5.00     4.03   2.80      2.78     2.57   1.75  1.05
# User 5455      0.95     4.05     4.05   2.81      2.79     2.44   1.76  1.03
# User 5456      0.95     4.07     5.00   2.82      2.80     2.57   2.42  1.02
#
# ...
